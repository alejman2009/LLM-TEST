# %%
import os
from tqdm import tqdm
import pickle

os.chdir("G:/UNIVERSIDAD/4ºCurso/TFG/ENTORNO-ML/Datasets")

print("Start")
dataset_pkl_file = "Dataset_opewebtext_full_ref.pkl"
with open(dataset_pkl_file, 'rb') as file:
    dataset = pickle.load(file)    
print("End prev.")
# Out:
# Start

# %%
with open("Dataset_opewebtext_full.txt", 'w',encoding='utf-8') as f:
    for data in tqdm(dataset):
        f.write(data['text'] + '\n')
print("End.")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 8013769/8013769 [23:12<00:00, 5756.59it/s]
