# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import mmap
import random
import pickle
import argparse
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

batch_size = 64 #32
block_size = 128 #128
max_iters = 200 #200
learning_rate = 3e-4
eval_iters = 156 #100
n_embd = 384
n_head = 8
n_layer = 8
dropout = 0.2
# Out:
# cuda

# %%
chars = ""
with open("vocab.txt", 'r', encoding='utf-8') as f:
        text = f.read()
        chars = sorted(list(set(text)))
        
vocab_size = len(chars)

# %%
string_to_int = { ch:i for i,ch in enumerate(chars) }
int_to_string = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [string_to_int[c] for c in s]
decode = lambda l: ''.join([int_to_string[i] for i in l])

#data = torch.tensor(encode(text), dtype=torch.long)

# %%
# memory map for using small snippets of text from a single file of any size
def get_random_chunk(split):
    filename = "output_train.txt" if split == 'train' else "output_val.txt"
    with open(filename, 'rb') as f:
        with mmap.mmap(f.fileno(), 0, access=mmap.ACCESS_READ) as mm:
            # Determine the file size and a random position to start reading
            file_size = len(mm)
            start_pos = random.randint(0, (file_size) - block_size*batch_size)

            # Seek to the random position and read the block of text
            mm.seek(start_pos)
            block = mm.read(block_size*batch_size-1)

            # Decode the block to a string, ignoring any invalid byte sequences
            decoded_block = block.decode('utf-8', errors='ignore').replace('\r', '')
            
            # Train and test splits
            data = torch.tensor(encode(decoded_block), dtype=torch.long)
            
    return data
        
def get_batch(split):
    data = get_random_chunk(split)
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train','val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y =get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # input of size (batch, time-step, channels)
        # output of size (batch, time-step, head size)
        B,T,C = x.shape
        k = self.key(x)   # (B,T,hs)
        q = self.query(x) # (B,T,hs)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * k.shape[-1]**-0.5 # (B, T, hs) @ (B, hs, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,hs)
        out = wei @ v # (B, T, T) @ (B, T, hs) -> (B, T, hs)
        return out

# [1, 0, 0]
# [1, 0.6, 0]
# [1, 0.6, 0.4]
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(head_size * num_heads, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1) # (B, T, F) -> (B, T, [h1, h1, h1, h1, h2, h2, h2, h2, h3, h3, h3, h3])
        out = self.dropout(self.proj(out))
        return out
    

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)
    
class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        y = self.sa(x)
        x = self.ln1(x + y)
        y = self.ffwd(x)
        x = self.ln2(x + y)
        return x
    
class LanguageModel(nn.Module):
    def __init__(self, vocab_size):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)
        
        
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, index, targets=None):
        B, T = index.shape
        
        
        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(index) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)
        
        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)
        
        return logits, loss
    
    def generate(self, index, max_new_tokens):
        # index is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            index_cond = index[:, -block_size:]
            # get the predictions
            logits, loss = self.forward(index_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            index_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            index = torch.cat((index, index_next), dim=1) # (B, T+1)
        return index

model = LanguageModel(vocab_size)
print('loading model parameters...')
# with open('model-01.pkl', 'rb') as f:
#     model = pickle.load(f)
print('loaded successfully!')
m = model.to(device)
# Out:
# loading model parameters...
# loaded successfully!

# %%
# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):
    #print(iter)
    if iter % eval_iters == 0:
        losses = estimate_loss()
    print(f"step: {iter}, train loss: {losses['train']:.3f}, val loss: {losses['val']:.3f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model.forward(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
print(loss.item())

with open('model-01.pkl', 'wb') as f:
    pickle.dump(model, f)
print('model saved')
# Out:
# step: 0, train loss: 10.430, val loss: 10.430
# step: 1, train loss: 10.430, val loss: 10.430
# step: 2, train loss: 10.430, val loss: 10.430
# step: 3, train loss: 10.430, val loss: 10.430
# step: 4, train loss: 10.430, val loss: 10.430
# step: 5, train loss: 10.430, val loss: 10.430
# step: 6, train loss: 10.430, val loss: 10.430
# step: 7, train loss: 10.430, val loss: 10.430
# step: 8, train loss: 10.430, val loss: 10.430
# step: 9, train loss: 10.430, val loss: 10.430
# step: 10, train loss: 10.430, val loss: 10.430
# step: 11, train loss: 10.430, val loss: 10.430
# step: 12, train loss: 10.430, val loss: 10.430
# step: 13, train loss: 10.430, val loss: 10.430
# step: 14, train loss: 10.430, val loss: 10.430
# step: 15, train loss: 10.430, val loss: 10.430
# step: 16, train loss: 10.430, val loss: 10.430
# step: 17, train loss: 10.430, val loss: 10.430
# step: 18, train loss: 10.430, val loss: 10.430
# step: 19, train loss: 10.430, val loss: 10.430
# step: 20, train loss: 10.430, val loss: 10.430
# step: 21, train loss: 10.430, val loss: 10.430
# step: 22, train loss: 10.430, val loss: 10.430
# step: 23, train loss: 10.430, val loss: 10.430
# step: 24, train loss: 10.430, val loss: 10.430
# step: 25, train loss: 10.430, val loss: 10.430
# step: 26, train loss: 10.430, val loss: 10.430
# step: 27, train loss: 10.430, val loss: 10.430
# step: 28, train loss: 10.430, val loss: 10.430
# step: 29, train loss: 10.430, val loss: 10.430
# step: 30, train loss: 10.430, val loss: 10.430
# step: 31, train loss: 10.430, val loss: 10.430
# step: 32, train loss: 10.430, val loss: 10.430
# step: 33, train loss: 10.430, val loss: 10.430
# step: 34, train loss: 10.430, val loss: 10.430
# step: 35, train loss: 10.430, val loss: 10.430
# step: 36, train loss: 10.430, val loss: 10.430
# step: 37, train loss: 10.430, val loss: 10.430
# step: 38, train loss: 10.430, val loss: 10.430
# step: 39, train loss: 10.430, val loss: 10.430
# step: 40, train loss: 10.430, val loss: 10.430
# step: 41, train loss: 10.430, val loss: 10.430
# step: 42, train loss: 10.430, val loss: 10.430
# step: 43, train loss: 10.430, val loss: 10.430
# step: 44, train loss: 10.430, val loss: 10.430
# step: 45, train loss: 10.430, val loss: 10.430
# step: 46, train loss: 10.430, val loss: 10.430
# step: 47, train loss: 10.430, val loss: 10.430
# step: 48, train loss: 10.430, val loss: 10.430
# step: 49, train loss: 10.430, val loss: 10.430
# step: 50, train loss: 10.430, val loss: 10.430
# step: 51, train loss: 10.430, val loss: 10.430
# step: 52, train loss: 10.430, val loss: 10.430
# step: 53, train loss: 10.430, val loss: 10.430
# step: 54, train loss: 10.430, val loss: 10.430
# step: 55, train loss: 10.430, val loss: 10.430
# step: 56, train loss: 10.430, val loss: 10.430
# step: 57, train loss: 10.430, val loss: 10.430
# step: 58, train loss: 10.430, val loss: 10.430
# step: 59, train loss: 10.430, val loss: 10.430
# step: 60, train loss: 10.430, val loss: 10.430
# step: 61, train loss: 10.430, val loss: 10.430
# step: 62, train loss: 10.430, val loss: 10.430
# step: 63, train loss: 10.430, val loss: 10.430
# step: 64, train loss: 10.430, val loss: 10.430
# step: 65, train loss: 10.430, val loss: 10.430
# step: 66, train loss: 10.430, val loss: 10.430
# step: 67, train loss: 10.430, val loss: 10.430
# step: 68, train loss: 10.430, val loss: 10.430
# step: 69, train loss: 10.430, val loss: 10.430
# step: 70, train loss: 10.430, val loss: 10.430
# step: 71, train loss: 10.430, val loss: 10.430
# step: 72, train loss: 10.430, val loss: 10.430
# step: 73, train loss: 10.430, val loss: 10.430
# step: 74, train loss: 10.430, val loss: 10.430
# step: 75, train loss: 10.430, val loss: 10.430
# step: 76, train loss: 10.430, val loss: 10.430
# step: 77, train loss: 10.430, val loss: 10.430
# step: 78, train loss: 10.430, val loss: 10.430
# step: 79, train loss: 10.430, val loss: 10.430
# step: 80, train loss: 10.430, val loss: 10.430
# step: 81, train loss: 10.430, val loss: 10.430
# step: 82, train loss: 10.430, val loss: 10.430
# step: 83, train loss: 10.430, val loss: 10.430
# step: 84, train loss: 10.430, val loss: 10.430
# step: 85, train loss: 10.430, val loss: 10.430
# step: 86, train loss: 10.430, val loss: 10.430
# step: 87, train loss: 10.430, val loss: 10.430
# step: 88, train loss: 10.430, val loss: 10.430
# step: 89, train loss: 10.430, val loss: 10.430
# step: 90, train loss: 10.430, val loss: 10.430
# step: 91, train loss: 10.430, val loss: 10.430
# step: 92, train loss: 10.430, val loss: 10.430
# step: 93, train loss: 10.430, val loss: 10.430
# step: 94, train loss: 10.430, val loss: 10.430
# step: 95, train loss: 10.430, val loss: 10.430
# step: 96, train loss: 10.430, val loss: 10.430
# step: 97, train loss: 10.430, val loss: 10.430
# step: 98, train loss: 10.430, val loss: 10.430
# step: 99, train loss: 10.430, val loss: 10.430
# step: 100, train loss: 10.430, val loss: 10.430
# step: 101, train loss: 10.430, val loss: 10.430
# step: 102, train loss: 10.430, val loss: 10.430
# step: 103, train loss: 10.430, val loss: 10.430
# step: 104, train loss: 10.430, val loss: 10.430
# step: 105, train loss: 10.430, val loss: 10.430
# step: 106, train loss: 10.430, val loss: 10.430
# step: 107, train loss: 10.430, val loss: 10.430
# step: 108, train loss: 10.430, val loss: 10.430
# step: 109, train loss: 10.430, val loss: 10.430
# step: 110, train loss: 10.430, val loss: 10.430
# step: 111, train loss: 10.430, val loss: 10.430
# step: 112, train loss: 10.430, val loss: 10.430
# step: 113, train loss: 10.430, val loss: 10.430
# step: 114, train loss: 10.430, val loss: 10.430
# step: 115, train loss: 10.430, val loss: 10.430
# step: 116, train loss: 10.430, val loss: 10.430
# step: 117, train loss: 10.430, val loss: 10.430
# step: 118, train loss: 10.430, val loss: 10.430
# step: 119, train loss: 10.430, val loss: 10.430
# step: 120, train loss: 10.430, val loss: 10.430
# step: 121, train loss: 10.430, val loss: 10.430
# step: 122, train loss: 10.430, val loss: 10.430
# step: 123, train loss: 10.430, val loss: 10.430
# step: 124, train loss: 10.430, val loss: 10.430
# step: 125, train loss: 10.430, val loss: 10.430
# step: 126, train loss: 10.430, val loss: 10.430
# step: 127, train loss: 10.430, val loss: 10.430
# step: 128, train loss: 10.430, val loss: 10.430
# step: 129, train loss: 10.430, val loss: 10.430
# step: 130, train loss: 10.430, val loss: 10.430
# step: 131, train loss: 10.430, val loss: 10.430
# step: 132, train loss: 10.430, val loss: 10.430
# step: 133, train loss: 10.430, val loss: 10.430
# step: 134, train loss: 10.430, val loss: 10.430
# step: 135, train loss: 10.430, val loss: 10.430
# step: 136, train loss: 10.430, val loss: 10.430
# step: 137, train loss: 10.430, val loss: 10.430
# step: 138, train loss: 10.430, val loss: 10.430
# step: 139, train loss: 10.430, val loss: 10.430
# step: 140, train loss: 10.430, val loss: 10.430
# step: 141, train loss: 10.430, val loss: 10.430
# step: 142, train loss: 10.430, val loss: 10.430
# step: 143, train loss: 10.430, val loss: 10.430
# step: 144, train loss: 10.430, val loss: 10.430
# step: 145, train loss: 10.430, val loss: 10.430
# step: 146, train loss: 10.430, val loss: 10.430
# step: 147, train loss: 10.430, val loss: 10.430
# step: 148, train loss: 10.430, val loss: 10.430
# step: 149, train loss: 10.430, val loss: 10.430
# step: 150, train loss: 10.430, val loss: 10.430
# step: 151, train loss: 10.430, val loss: 10.430
# step: 152, train loss: 10.430, val loss: 10.430
# step: 153, train loss: 10.430, val loss: 10.430
# step: 154, train loss: 10.430, val loss: 10.430
# step: 155, train loss: 10.430, val loss: 10.430
# step: 156, train loss: 2.352, val loss: 2.341
# step: 157, train loss: 2.352, val loss: 2.341
# step: 158, train loss: 2.352, val loss: 2.341
# step: 159, train loss: 2.352, val loss: 2.341
# step: 160, train loss: 2.352, val loss: 2.341
# step: 161, train loss: 2.352, val loss: 2.341
# step: 162, train loss: 2.352, val loss: 2.341
# step: 163, train loss: 2.352, val loss: 2.341
# step: 164, train loss: 2.352, val loss: 2.341
# step: 165, train loss: 2.352, val loss: 2.341
# step: 166, train loss: 2.352, val loss: 2.341
# step: 167, train loss: 2.352, val loss: 2.341
# step: 168, train loss: 2.352, val loss: 2.341
# step: 169, train loss: 2.352, val loss: 2.341
# step: 170, train loss: 2.352, val loss: 2.341
# step: 171, train loss: 2.352, val loss: 2.341
# step: 172, train loss: 2.352, val loss: 2.341
# step: 173, train loss: 2.352, val loss: 2.341
# step: 174, train loss: 2.352, val loss: 2.341
# step: 175, train loss: 2.352, val loss: 2.341
# step: 176, train loss: 2.352, val loss: 2.341
# step: 177, train loss: 2.352, val loss: 2.341
# step: 178, train loss: 2.352, val loss: 2.341
# step: 179, train loss: 2.352, val loss: 2.341
# step: 180, train loss: 2.352, val loss: 2.341
# step: 181, train loss: 2.352, val loss: 2.341
# step: 182, train loss: 2.352, val loss: 2.341
# step: 183, train loss: 2.352, val loss: 2.341
# step: 184, train loss: 2.352, val loss: 2.341
# step: 185, train loss: 2.352, val loss: 2.341
# step: 186, train loss: 2.352, val loss: 2.341
# step: 187, train loss: 2.352, val loss: 2.341
# step: 188, train loss: 2.352, val loss: 2.341
# step: 189, train loss: 2.352, val loss: 2.341
# step: 190, train loss: 2.352, val loss: 2.341
# step: 191, train loss: 2.352, val loss: 2.341
# step: 192, train loss: 2.352, val loss: 2.341
# step: 193, train loss: 2.352, val loss: 2.341
# step: 194, train loss: 2.352, val loss: 2.341
# step: 195, train loss: 2.352, val loss: 2.341
# step: 196, train loss: 2.352, val loss: 2.341
# step: 197, train loss: 2.352, val loss: 2.341
# step: 198, train loss: 2.352, val loss: 2.341
# step: 199, train loss: 2.352, val loss: 2.341
# 2.086686611175537
# model saved

# %%
prompt = 'Hola?'
context = torch.tensor(encode(prompt), dtype=torch.long, device=device)
generated_chars = decode(m.generate(context.unsqueeze(0), max_new_tokens=100)[0].tolist())
print(generated_chars)
# Out:
# Hola? ty rraromeanby font. hpoy ar 堯1e – 2 kee Wh cgron pr Ond tand 162 ppe K𝤬.pro7
# Rmerintha, wicacoyori
