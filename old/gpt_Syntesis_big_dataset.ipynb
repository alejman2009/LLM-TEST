# %% [markdown]
# # Dataset

# %% [markdown]
# ## Installing Required Software

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
# !pip install datasets
# !pip install google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client
# Out:
# Requirement already satisfied: datasets in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (2.18.0)
# Requirement already satisfied: filelock in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (1.26.0)
# Requirement already satisfied: pyarrow>=12.0.0 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (2.2.1)
# Requirement already satisfied: requests>=2.19.0 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (0.21.4)
# Requirement already satisfied: packaging in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from huggingface-hub>=0.19.4->datasets) (4.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from requests>=2.19.0->datasets) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from requests>=2.19.0->datasets) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: colorama in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: google-auth in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (2.29.0)
# Requirement already satisfied: google-auth-oauthlib in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (1.2.0)
# Requirement already satisfied: google-auth-httplib2 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (0.2.0)
# Requirement already satisfied: google-api-python-client in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (2.123.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from google-auth) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from google-auth) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from google-auth) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from google-auth-oauthlib) (1.4.0)
# Requirement already satisfied: httplib2>=0.19.0 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from google-api-python-client) (2.18.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.23.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in g:\universidad\4ºcurso\tfg\entorno-ml\cuda\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Preparing the dataset

# %%
import os
from tqdm import tqdm

'''
from google.colab import userdata
from google.colab import drive
userdata.get('LLM')
drive.mount('/content/drive')

os.chdir("/content/drive/MyDrive/compartir/Documentacion/TFG/intento_collab/Datasets")
'''

os.chdir("G:/UNIVERSIDAD/4ºCurso/TFG/ENTORNO-ML/Datasets")

# %%
from datasets import load_dataset
dataset = load_dataset("Skylion007/openwebtext", split="train",trust_remote_code=True)
# Out:
# Generating train split:   0%|          | 0/8013769 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\builder.py:1744, in GeneratorBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1743 example = self.info.features.encode_example(record) if self.info.features is not None else record
# -> 1744 writer.write(example, key)
#    1745 num_examples_progress_update += 1
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\arrow_writer.py:499, in ArrowWriter.write(self, example, key, writer_batch_size)
#     497     self.hkey_record = []
# --> 499 self.write_examples_on_file()
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\arrow_writer.py:457, in ArrowWriter.write_examples_on_file(self)
#     453         batch_examples[col] = [
#     454             row[0][col].to_pylist()[0] if isinstance(row[0][col], (pa.Array, pa.ChunkedArray)) else row[0][col]
#     455             for row in self.current_examples
#     456         ]
# --> 457 self.write_batch(batch_examples=batch_examples)
#     458 self.current_examples = []
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\arrow_writer.py:571, in ArrowWriter.write_batch(self, batch_examples, writer_batch_size)
#     570 pa_table = pa.Table.from_arrays(arrays, schema=schema)
# --> 571 self.write_table(pa_table, writer_batch_size)
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\arrow_writer.py:589, in ArrowWriter.write_table(self, pa_table, writer_batch_size)
#     588 self._num_examples += pa_table.num_rows
# --> 589 self.pa_writer.write_table(pa_table, writer_batch_size)
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\pyarrow\ipc.pxi:529, in pyarrow.lib._CRecordBatchWriter.write_table()
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\pyarrow\error.pxi:88, in pyarrow.lib.check_status()
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\fsspec\implementations\local.py:373, in LocalFileOpener.write(self, *args, **kwargs)
#     372 def write(self, *args, **kwargs):
# --> 373     return self.f.write(*args, **kwargs)
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\builder.py:1753, in GeneratorBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1752 num_shards = shard_id + 1
# -> 1753 num_examples, num_bytes = writer.finalize()
#    1754 writer.close()
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\arrow_writer.py:598, in ArrowWriter.finalize(self, close_stream)
#     597     self.hkey_record = []
# --> 598 self.write_examples_on_file()
#     599 # If schema is known, infer features even if no examples were written
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\arrow_writer.py:457, in ArrowWriter.write_examples_on_file(self)
#     453         batch_examples[col] = [
#     454             row[0][col].to_pylist()[0] if isinstance(row[0][col], (pa.Array, pa.ChunkedArray)) else row[0][col]
#     455             for row in self.current_examples
#     456         ]
# --> 457 self.write_batch(batch_examples=batch_examples)
#     458 self.current_examples = []
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\arrow_writer.py:571, in ArrowWriter.write_batch(self, batch_examples, writer_batch_size)
#     570 pa_table = pa.Table.from_arrays(arrays, schema=schema)
# --> 571 self.write_table(pa_table, writer_batch_size)
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\arrow_writer.py:589, in ArrowWriter.write_table(self, pa_table, writer_batch_size)
#     588 self._num_examples += pa_table.num_rows
# --> 589 self.pa_writer.write_table(pa_table, writer_batch_size)
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\pyarrow\ipc.pxi:529, in pyarrow.lib._CRecordBatchWriter.write_table()
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\pyarrow\error.pxi:88, in pyarrow.lib.check_status()
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\fsspec\implementations\local.py:373, in LocalFileOpener.write(self, *args, **kwargs)
#     372 def write(self, *args, **kwargs):
# --> 373     return self.f.write(*args, **kwargs)
#
# OSError: [Errno 28] No space left on device
#
# The above exception was the direct cause of the following exception:
#
# DatasetGenerationError                    Traceback (most recent call last)
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\builder.py:959, in DatasetBuilder.download_and_prepare.<locals>.incomplete_dir(dirname)
#     958 try:
# --> 959     yield tmp_dir
#     960     if os.path.isdir(dirname):
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\builder.py:1005, in DatasetBuilder.download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, ignore_verifications, try_from_hf_gcs, dl_manager, base_path, use_auth_token, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#    1004         prepare_split_kwargs["num_proc"] = num_proc
# -> 1005     self._download_and_prepare(
#    1006         dl_manager=dl_manager,
#    1007         verification_mode=verification_mode,
#    1008         **prepare_split_kwargs,
#    1009         **download_and_prepare_kwargs,
#    1010     )
#    1011 # Sync info
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\builder.py:1767, in GeneratorBasedBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs)
#    1766 def _download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs):
# -> 1767     super()._download_and_prepare(
#    1768         dl_manager,
#    1769         verification_mode,
#    1770         check_duplicate_keys=verification_mode == VerificationMode.BASIC_CHECKS
#    1771         or verification_mode == VerificationMode.ALL_CHECKS,
#    1772         **prepare_splits_kwargs,
#    1773     )
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\builder.py:1100, in DatasetBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#    1098 try:
#    1099     # Prepare split will record examples associated to the split
# -> 1100     self._prepare_split(split_generator, **prepare_split_kwargs)
#    1101 except OSError as e:
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\builder.py:1605, in GeneratorBasedBuilder._prepare_split(self, split_generator, check_duplicate_keys, file_format, num_proc, max_shard_size)
#    1604 with pbar:
# -> 1605     for job_id, done, content in self._prepare_split_single(
#    1606         gen_kwargs=gen_kwargs, job_id=job_id, **_prepare_split_args
#    1607     ):
#    1608         if done:
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\builder.py:1762, in GeneratorBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1761         e = e.__context__
# -> 1762     raise DatasetGenerationError("An error occurred while generating the dataset") from e
#    1764 yield job_id, True, (total_num_examples, total_num_bytes, writer._features, num_shards, shard_lengths)
#
# DatasetGenerationError: An error occurred while generating the dataset
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 from datasets import load_dataset
# ----> 2 dataset = load_dataset("Skylion007/openwebtext", split="train",trust_remote_code=True)
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\load.py:2582, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2579 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#    2581 # Download and prepare data
# -> 2582 builder_instance.download_and_prepare(
#    2583     download_config=download_config,
#    2584     download_mode=download_mode,
#    2585     verification_mode=verification_mode,
#    2586     try_from_hf_gcs=try_from_hf_gcs,
#    2587     num_proc=num_proc,
#    2588     storage_options=storage_options,
#    2589 )
#    2591 # Build dataset for splits
#    2592 keep_in_memory = (
#    2593     keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    2594 )
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\builder.py:985, in DatasetBuilder.download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, ignore_verifications, try_from_hf_gcs, dl_manager, base_path, use_auth_token, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#     982 self._check_manual_download(dl_manager)
#     984 # Create a tmp dir and rename to self._output_dir on successful exit.
# --> 985 with incomplete_dir(self._output_dir) as tmp_output_dir:
#     986     # Temporarily assign _output_dir to tmp_data_dir to avoid having to forward
#     987     # it to every sub function.
#     988     with temporary_assignment(self, "_output_dir", tmp_output_dir):
#     989         # Try to download the already prepared dataset files
#     990         downloaded_from_gcs = False
#
# File D:\Anaconda\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     153     value = typ()
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#     160     return exc is not value
#
# File G:\UNIVERSIDAD\4ºCurso\TFG\ENTORNO-ML\cuda\Lib\site-packages\datasets\builder.py:966, in DatasetBuilder.download_and_prepare.<locals>.incomplete_dir(dirname)
#     964 finally:
#     965     if os.path.exists(tmp_dir):
# --> 966         shutil.rmtree(tmp_dir)
#
# File D:\Anaconda\Lib\shutil.py:759, in rmtree(path, ignore_errors, onerror, dir_fd)
#     757     # can't continue even if onerror hook returns
#     758     return
# --> 759 return _rmtree_unsafe(path, onerror)
#
# File D:\Anaconda\Lib\shutil.py:622, in _rmtree_unsafe(path, onerror)
#     620             os.unlink(fullname)
#     621         except OSError:
# --> 622             onerror(os.unlink, fullname, sys.exc_info())
#     623 try:
#     624     os.rmdir(path)
#
# File D:\Anaconda\Lib\shutil.py:620, in _rmtree_unsafe(path, onerror)
#     618 else:
#     619     try:
# --> 620         os.unlink(fullname)
#     621     except OSError:
#     622         onerror(os.unlink, fullname, sys.exc_info())
#
# PermissionError: [WinError 32] El proceso no tiene acceso al archivo porque está siendo utilizado por otro proceso: 'C:/Users/Alex-PC/.cache/huggingface/datasets/Skylion007___openwebtext/plain_text/1.0.0/6f68e85c16ccc770c0dd489f4008852ea9633604995addd0cd76e293aed9e521.incomplete\\openwebtext-train-00000-00068-of-NNNNN.arrow'

# %% [markdown]
# # Procesado del dataset

# %%
text = ""
for data in tqdm(dataset):
    text += data['text']

chars = sorted(list(set(text)))
vocab_size = len(chars)
print(chars)

# %% [markdown]
# Almacenamiento del dataset como un formato .pkl

# %%
import pickle
dataset_pkl_file = "LLM_Dataset_opewebtext_full.pkl"
with open(dataset_pkl_file, 'wb') as file:
    pickle.dump(text, file)
